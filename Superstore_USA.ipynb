# %% [markdown]
# 1 . load this data in sql and in pandas with a relation in sql <br>
# 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table <br>
# 3 . Find out how return that we ahve recived and with a product id <br>
# 4 . try  to join order and return data both in sql and pandas <br>
# 5 . Try to find out how many unique customer that we have <br>
# 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region <br>
# 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset <br>
# 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date<br>
# 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days <br>
# 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well <br>
# 11 . Gorup by region and find out which region is more profitable <br>
# 12 . Try to find out overalll in which country we are giving more didscount <br>
# 13 . Give me a list of unique postal code <br>
# 14 . which customer segement is more profitalble find it out . <br>
# 15 . try to find out the 10th most loss making product catagory . <br>
# 16 . Try to find out 10 top  product with highest margins <br>

# %%
import pandas as pd

# %% [markdown]
# ## 1 . load this data in sql and in pandas with a relation in sql

# %%
df_orders=pd.read_excel('Superstore_USA.xlsx',sheet_name = 'Orders')
df_returns=pd.read_excel('Superstore_USA.xlsx',sheet_name = 'Returns')
df_users=pd.read_excel('Superstore_USA.xlsx',sheet_name = 'Users')

# %%
df_orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
df_returns.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
df_returns.nunique()
# Out:
# Order ID    1634
# Status         1
# dtype: int64

# %%
df_users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
df_users.nunique()
# Out:
# Region     4
# Manager    4
# dtype: int64

# %%
df_orders.shape
# Out:
# (9426, 24)

# %%
df_orders.nunique()
# Out:
# Row ID                  9426
# Order Priority             6
# Discount                  16
# Unit Price               751
# Shipping Cost            652
# Customer ID             2703
# Customer Name           2703
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name            1263
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1424
# Postal Code             1697
# Order Date              1419
# Ship Date               1450
# Profit                  8984
# Quantity ordered new     112
# Sales                   8674
# Order ID                6455
# dtype: int64

# %%
df_orders['Order Priority'].value_counts()
# Out:
# High             1970
# Low              1926
# Not Specified    1881
# Medium           1844
# Critical         1804
# Critical            1
# Name: Order Priority, dtype: int64

# %%
df_orders['Ship Mode'].value_counts()
# Out:
# Regular Air       7036
# Delivery Truck    1283
# Express Air       1107
# Name: Ship Mode, dtype: int64

# %%
df_orders['Customer Segment'].value_counts()
# Out:
# Corporate         3375
# Home Office       2316
# Consumer          1894
# Small Business    1841
# Name: Customer Segment, dtype: int64

# %%
df_orders['Product Category'].value_counts()
# Out:
# Office Supplies    5181
# Technology         2312
# Furniture          1933
# Name: Product Category, dtype: int64

# %%
df_orders['Product Container'].value_counts()
# Out:
# Small Box     4887
# Wrap Bag      1312
# Small Pack    1067
# Jumbo Drum     703
# Jumbo Box      590
# Large Box      457
# Medium Box     410
# Name: Product Container, dtype: int64

# %%
df_orders['Region'].value_counts()
# Out:
# Central    2899
# East       2289
# West       2284
# South      1954
# Name: Region, dtype: int64

# %% [markdown]
# ## 2 . while loading this data you dont have to create a table manually you can use any automated approach to create a table and load a data in bulk in table

# %%
## I need help in this step

# %% [markdown]
# ## 3 . Find out how return that we have recived and with a product id

# %%
df_returns.nunique()
# Out:
# Order ID    1634
# Status         1
# dtype: int64

# %%
len(df_returns)
# Out:
# 1634

# %% [markdown]
# ## 4 . try  to join order and return data both in sql and pandas

# %%
q=pd.merge(df_orders,df_returns,how='left')
q['Status'].fillna("Delivered",inplace=True)
q.isnull().sum()
q
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# ## 5 . Try to find out how many unique customer that we have

# %%
df_orders['Customer ID'].nunique()
# Out:
# 2703

# %% [markdown]
# ## 6 . try to find out in how many regions we are selling a product and who is a manager for a respective region

# %%
df_new=pd.merge(df_orders,df_users)
pd.DataFrame(df_new.groupby(['Region','Manager'])['Product Name'].count().reset_index())
# Out:
#     Region  Manager  Product Name
# 0  Central    Chris          2899
# 1     East     Erin          2289
# 2    South      Sam          1954
# 3     West  William          2284

# %% [markdown]
# ## 7 . find out how many different differnet shipement mode that we have and what is a percentage usablity of all the shipment mode with respect to dataset

# %%
(df_orders['Ship Mode'].value_counts())/len(df_orders)*100
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64

# %% [markdown]
# ## 8 . Create a new coulmn and try to find our a diffrence between order date and shipment date

# %%
df_orders.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
df_orders['Order Date'] = pd.to_datetime(df_orders['Order Date'])
df_orders['Ship Date'] = pd.to_datetime(df_orders['Ship Date'])

# %%
df_orders['Difference Date']=df_orders['Ship Date']-df_orders['Order Date']

# %%
df_orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df_orders.dtypes
# Out:
# Row ID                            int64
# Order Priority                   object
# Discount                        float64
# Unit Price                      float64
# Shipping Cost                   float64
# Customer ID                       int64
# Customer Name                    object
# Ship Mode                        object
# Customer Segment                 object
# Product Category                 object
# Product Sub-Category             object
# Product Container                object
# Product Name                     object
# Product Base Margin             float64
# Region                           object
# State or Province                object
# City                             object
# Postal Code                       int64
# Order Date               datetime64[ns]
# Ship Date                datetime64[ns]
# Profit                          float64
# Quantity ordered new              int64
# Sales                           float64
# ...

# %%
df_orders['Difference Date']=df_orders['Difference Date'].astype(str)

# %%
#df_orders['Difference Date']=df_orders['Difference Date'].astype('object')

# %%
df_orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df_orders.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
df_orders['Difference Date']=[i[0:1] for i in df_orders['Difference Date']]

# %%
df_orders.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# ...

# %%
df_orders['Difference Date']=df_orders['Difference Date'].astype(int)

# %%
df_orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %% [markdown]
# ## 9 . base on question number 8 find out for which order id we have shipment duration more than 10 days

# %%
len(df_orders[df_orders['Difference Date']>10])
# Out:
# 0

# %% [markdown]
# ## 10 . Try to find out a list of a returned order which sihpment duration was more then 15 days and find out that region manager as well

# %%
## no shipment duration more than 15 days

# %% [markdown]
# ## 11 . Gorup by region and find out which region is more profitable

# %%
df_orders.groupby('Region')['Profit'].sum()
# Out:
# Region
# Central    519825.567067
# East       377566.186045
# South      104201.192420
# West       310849.453897
# Name: Profit, dtype: float64

# %%
pd.DataFrame(df_orders.groupby('Region')['Profit'].sum().reset_index()).iloc[0,0]
# Out:
# 'Central'

# %% [markdown]
# ## 12 . Try to find out overalll in which country we are giving more didscount

# %%
## there is no country column so I took city instead

# %%
df_orders
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
(pd.DataFrame(df_orders.groupby('City')['Discount'].sum().reset_index())).sort_values('City',ascending=False).iloc[0,0]
# Out:
# 'Yuma'

# %% [markdown]
# ## 13 . Give me a list of unique postal code

# %%
list(df_orders['Postal Code'].unique())
# Out:
# [60101,
#  98221,
#  91776,
#  95123,
#  2724,
#  3110,
#  8101,
#  8109,
#  7203,
#  2907,
#  55372,
#  11787,
#  13210,
#  59405,
#  59601,
#  59801,
#  68005,
#  10012,
#  92653,
#  92677,
#  92530,
#  92630,
#  90712,
#  93534,
#  90260,
#  97405,
#  97526,
#  97030,
#  97123,
#  97303,
#  62002,
#  98373,
#  98052,
#  75019,
#  23834,
#  62701,
#  60107,
#  60477,
#  14150,
#  12180,
#  77642,
#  75080,
#  77471,
#  78664,
#  75088,
#  24153,
#  94043,
#  92563,
#  94559,
#  10177,
#  2917,
#  5401,
#  4070,
#  2331,
#  8830,
#  8701,
#  7470,
#  7481,
#  5201,
#  97035,
#  44708,
#  45231,
#  44105,
#  95687,
#  5451,
#  94591,
#  70056,
#  22102,
#  60601,
#  66209,
#  66215,
#  66502,
#  66062,
#  6510,
#  4401,
#  4005,
#  2129,
#  2038,
#  1852,
#  1752,
#  2067,
#  3820,
#  8618,
#  7644,
#  7110,
#  8861,
#  7095,
#  2895,
#  97128,
#  97504,
#  98103,
#  84118,
#  84041,
#  93277,
#  76903,
#  78207,
#  60004,
#  94952,
#  1510,
#  1106,
#  1880,
#  6401,
#  6360,
# ...

# %% [markdown]
# ## 14 . which customer segement is more profitalble find it out .

# %%
(pd.DataFrame(df_orders.groupby('Customer Segment')['Profit'].sum().reset_index())).sort_values('Customer Segment',ascending=False).iloc[0,0]
# Out:
# 'Small Business'

# %% [markdown]
# ## 15 . try to find out the 10th most loss making product catagory .

# %%
(pd.DataFrame(df_orders.groupby('Product Category')['Profit'].sum().reset_index())).sort_values('Profit',ascending=True)
# Out:
#   Product Category         Profit
# 0        Furniture  177354.298188
# 1  Office Supplies  451990.216492
# 2       Technology  683097.884748

# %%
## there is only 3 product category so I will try to answer it base on Product Sub-Category

# %%
(pd.DataFrame(df_orders.groupby('Product Sub-Category')['Profit'].sum().reset_index())).sort_values('Profit',ascending=True).iloc[9,0]
# Out:
# 'Computer Peripherals'

# %% [markdown]
# ## 16 . Try to find out 10 top  product with highest margins

# %%
(pd.DataFrame(df_orders.groupby('Product Name')['Product Base Margin'].sum().reset_index())).sort_values('Product Base Margin',ascending=False).iloc[0:10,:]
# Out:
#                                            Product Name  Product Base Margin
# 557           Global High-Back Leather Tilter, Burgundy                19.98
# 291   BoxOffice By Design Rectangular and Half-Moon ...                18.33
# 260                     Bevis 36 x 72 Conference Tables                16.38
# 142                Adesso Programmable 142-Key Keyboard                15.45
# 95                                          Accessory36                14.11
# 824   Office Star - Mid Back Dual function Ergonomic...                13.64
# 822   Office Star - Contemporary Task Swivel chair w...                13.26
# 761                         Microsoft Internet Keyboard                13.21
# 1001                                       StarTAC 7760                12.98
# 940   Serrated Blade or Curved Handle Hand Letter Op...                12.60

# %%
df_orders[['Product Name','Product Base Margin']].sort_values('Product Base Margin',ascending=False).iloc[0:10,:]
# Out:
#                                            Product Name  Product Base Margin
# 9145                                        Accessory27                 0.85
# 4756                                         Accessory4                 0.85
# 7607                                        Accessory27                 0.85
# 5672                                         Accessory4                 0.85
# 4168                  Sterling Rubber Bands by Alliance                 0.85
# 807                                         Accessory27                 0.85
# 816                                         Accessory27                 0.85
# 3994  Office Impressions Heavy Duty Welded Shelving ...                 0.85
# 2138                  Sterling Rubber Bands by Alliance                 0.85
# 7202  Office Impressions Heavy Duty Welded Shelving ...                 0.85

# %%
df_orders[['Product Name','Product Base Margin']].sort_values('Product Base Margin',ascending=False).iloc[0:10,0]
# Out:
# 9145                                          Accessory27
# 4756                                           Accessory4
# 7607                                          Accessory27
# 5672                                           Accessory4
# 4168                    Sterling Rubber Bands by Alliance
# 807                                           Accessory27
# 816                                           Accessory27
# 3994    Office Impressions Heavy Duty Welded Shelving ...
# 2138                    Sterling Rubber Bands by Alliance
# 7202    Office Impressions Heavy Duty Welded Shelving ...
# Name: Product Name, dtype: object
